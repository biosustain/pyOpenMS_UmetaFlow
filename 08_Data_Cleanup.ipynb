# %%
import numpy as np
import pandas as pd
import glob
import os

# %%
DF_features= pd.read_csv(os.path.join("results", "FeatureMatrix.tsv"), sep="\t")
DF_features
# Out:
#                      Unnamed: 0  Pool.mzML  TreatmentDummy.mzML   adduct  \
# m/z        RT(s)
# 214.006269 142.3125           0  193134.20            193134.20  [M+Na]+
# 408.919430 118.0461           1   81530.50             81530.50   [M+H]+
# 343.197620 478.0524           2  144065.90            144065.90   [M+H]+
# 373.170996 203.5428           3   37901.68             37901.68   [M+H]+
# 444.031680 264.3329           4  149058.70            149058.70   [M+H]+
# ...                         ...        ...                  ...      ...
# 245.113169 164.1231        1105  982292.30            982292.30   [M+H]+
# 519.288579 483.0724        1106   71923.90             71923.90   [M+H]+
# 490.214517 480.5625        1107  203291.80            203291.80   [M+H]+
# 383.228984 526.7431        1108   56069.77             56069.77   [M+H]+
# 855.066338 250.6024        1109   52115.23             52115.23   [M+H]+
#
#                             Pool.mzML_IDs  TreatmentDummy.mzML_IDs  \
# m/z        RT(s)
# 214.006269 142.3125      1678804783366245      2033893695513758753
# 408.919430 118.0461     24313610088430505     16088509072498140707
# 343.197620 478.0524     61175644737115367     17086045535948683501
# 373.170996 203.5428     76036548048055670     13215169682980104525
# 444.031680 264.3329     90715253692421563      2592034239564004223
# ...                                   ...                      ...
# 245.113169 164.1231  18357450581163840485      2989509035928019993
# 519.288579 483.0724  18370378419443880244      4072289981989561970
# 490.214517 480.5625  18393588724740018489     18392485952725945707
# 383.228984 526.7431  18413609945502784175      4584721906901708538
# 855.066338 250.6024  18416027721767113660     12789982500143628693
#
#                     Pool_CSI:FingerID_molecularFormula Pool_CSI:FingerID_name  \
# m/z        RT(s)
# 214.006269 142.3125                                  0                      0
# 408.919430 118.0461                                  0                      0
# 343.197620 478.0524                                  0                      0
# 373.170996 203.5428                                  0                      0
# 444.031680 264.3329                                  0                      0
# ...                                                ...                    ...
# 245.113169 164.1231                                  0                      0
# 519.288579 483.0724                                  0                      0
# 490.214517 480.5625                                  0                      0
# 383.228984 526.7431                                  0                      0
# 855.066338 250.6024                                  0                      0
#
#                     Pool_CSI:FingerID_InChI Pool_CSI:FingerID_smiles  ...  \
# m/z        RT(s)                                                      ...
# 214.006269 142.3125                       0                        0  ...
# 408.919430 118.0461                       0                        0  ...
# 343.197620 478.0524                       0                        0  ...
# 373.170996 203.5428                       0                        0  ...
# 444.031680 264.3329                       0                        0  ...
# ...                                     ...                      ...  ...
# 245.113169 164.1231                       0                        0  ...
# 519.288579 483.0724                       0                        0  ...
# 490.214517 480.5625                       0                        0  ...
# 383.228984 526.7431                       0                        0  ...
# 855.066338 250.6024                       0                        0  ...
#
#                     TreatmentDummy_SIRIUS_molecularFormula  \
# m/z        RT(s)
# 214.006269 142.3125                                      0
# 408.919430 118.0461                                      0
# 343.197620 478.0524                                      0
# 373.170996 203.5428                                      0
# 444.031680 264.3329                                      0
# ...                                                    ...
# 245.113169 164.1231                             C11H16N3O2
# 519.288579 483.0724                                      0
# 490.214517 480.5625                                      0
# 383.228984 526.7431                                      0
# 855.066338 250.6024                                      0
#
#                      TreatmentDummy_SIRIUS_explainedIntensity  \
# m/z        RT(s)
# 214.006269 142.3125                                  0.000000
# 408.919430 118.0461                                  0.000000
# 343.197620 478.0524                                  0.000000
# 373.170996 203.5428                                  0.000000
# 444.031680 264.3329                                  0.000000
# ...                                                       ...
# 245.113169 164.1231                                  0.752862
# 519.288579 483.0724                                  0.000000
# 490.214517 480.5625                                  0.000000
# 383.228984 526.7431                                  0.000000
# 855.066338 250.6024                                  0.000000
#
#                     TreatmentDummy_CANOPUS_pathway  \
# m/z        RT(s)
# 214.006269 142.3125                              0
# 408.919430 118.0461                              0
# 343.197620 478.0524                              0
# 373.170996 203.5428                              0
# 444.031680 264.3329                              0
# ...                                            ...
# 245.113169 164.1231       Amino acids and Peptides
# 519.288579 483.0724                              0
# 490.214517 480.5625                              0
# 383.228984 526.7431                              0
# 855.066338 250.6024                              0
#
#                     TreatmentDummy_CANOPUS_superclass  \
# m/z        RT(s)
# 214.006269 142.3125                                 0
# 408.919430 118.0461                                 0
# 343.197620 478.0524                                 0
# 373.170996 203.5428                                 0
# 444.031680 264.3329                                 0
# ...                                               ...
# 245.113169 164.1231                    Small peptides
# 519.288579 483.0724                                 0
# 490.214517 480.5625                                 0
# 383.228984 526.7431                                 0
# 855.066338 250.6024                                 0
#
#                     TreatmentDummy_CANOPUS_class  \
# m/z        RT(s)
# 214.006269 142.3125                            0
# 408.919430 118.0461                            0
# 343.197620 478.0524                            0
# 373.170996 203.5428                            0
# 444.031680 264.3329                            0
# ...                                          ...
# 245.113169 164.1231                   Dipeptides
# 519.288579 483.0724                            0
# 490.214517 480.5625                            0
# 383.228984 526.7431                            0
# 855.066338 250.6024                            0
#
#                     TreatmentDummy_CANOPUS_most specific class  SCANS  \
# m/z        RT(s)
# 214.006269 142.3125                                          0    0.0
# 408.919430 118.0461                                          0    0.0
# 343.197620 478.0524                                          0    0.0
# 373.170996 203.5428                                          0    0.0
# 444.031680 264.3329                                          0    0.0
# ...                                                        ...    ...
# 245.113169 164.1231                                   Peptides  101.0
# 519.288579 483.0724                                          0    0.0
# 490.214517 480.5625                                          0    0.0
# 383.228984 526.7431                                          0    0.0
# 855.066338 250.6024                                          0    0.0
#
#                     SpectralMatch SpectralMatch_smiles GNPS
# m/z        RT(s)
# 214.006269 142.3125             0                    0    0
# 408.919430 118.0461             0                    0    0
# 343.197620 478.0524             0                    0    0
# 373.170996 203.5428             0                    0    0
# 444.031680 264.3329             0                    0    0
# ...                           ...                  ...  ...
# 245.113169 164.1231             0                    0    0
# 519.288579 483.0724             0                    0    0
# 490.214517 480.5625             0                    0    0
# 383.228984 526.7431             0                    0    0
# 855.066338 250.6024             0                    0    0
#
# [1110 rows x 30 columns]

# %% [markdown]
# `1) Filter the feature matrix (optional)`

# %%
path= os.path.join("results", "interim", "analysis")
isExist= os.path.exists(path)
if not isExist:
    os.mkdir(path)

# %% [markdown]
# a (i) Remove all features detected in negative controls (make sure there is no cross-contamination)

# %%
media_list= [r"ISP2", r"FPY12", r"DNPM"] # different media/conditions (treatments)
for medium in media_list:
    Features_flt=DF_features.filter(regex=fr"{medium}")
    blanks= Features_flt.filter(regex="blank", axis= 1) 
    blanks = blanks.fillna(0)
    blanks= blanks.transpose()
    dictionary = {}
    cols= blanks.columns
    for i, col in enumerate(cols):
        dictionary[i] = np.count_nonzero(blanks[col]) / len(blanks[col])
    column_idx = [key for key, value in dictionary.items() if value >= 0.5] #Remove features that appear most frequently (in more than 50% of the samples) in the negative controls
    print(dictionary)
    blank_features= blanks.iloc[:, column_idx] 
    cols= blank_features.columns
    Features_flt= Features_flt.transpose()
    Features_nb= Features_flt.drop(columns= cols)
    Features_nb= Features_nb.dropna(how="all")
    blanks=blanks.transpose()
    blank_cols= blanks.columns
    Features_nb= Features_flt.drop(columns=blank_cols)
    filename= os.path.join(path, "No_NC_"+ medium + "_DF_features.csv")
    Features_nb.to_csv(filename, sep="\t")

# %% [markdown]
# a (ii) Or if there are multiple replicates, remove only the features detected in more than 50% of all the negative controls (or blanks)

# %%
media_list= [r"ISP2", r"FPY12", r"DNPM"] # different media/conditions (treatments)
for medium in media_list:
    Features_flt=DF_features.filter(regex=fr"{medium}")
    blanks= Features_flt.filter(regex="blank", axis= 1) 
    blanks = blanks.fillna(0)
    blanks= blanks.transpose()
    cols= blanks.columns
    Features_flt= Features_flt.transpose()
    Features_nb= Features_flt.drop(columns= cols)
    Features_nb= Features_nb.dropna(how="all")
    blanks=blanks.transpose()
    blank_cols= blanks.columns
    Features_flt= Features_flt.transpose()
    Features_nb= Features_flt.drop(columns=blank_cols)
    filename= os.path.join(path, "No_NC_"+ medium + "_DF_features.csv")
    Features_nb.to_csv(filename, sep="\t")

# %% [markdown]
# b) Replace the features that have lower intensity than 10^4 with NaN (noise for Orbitrap instruments)

# %%
def noise_flt(csvfile):   
    Features= pd.read_csv(csvfile, sep="\t")
    Features= Features.set_index(["m/z", "RT (s)"])
    Features= Features.sort_index(axis=1) 
    cols= Features.columns
    Features[cols] = Features[cols].replace({0:np.nan})
    Features[Features<10000] = np.nan
    Featuresnew=Features.dropna(how="all")
    Featuresnew = Featuresnew.fillna(0)
    DF= Featuresnew.reset_index()
    file_path = os.path.join(os.path.dirname(csvfile), 'noise_thr_' + os.path.basename(csvfile)[6:])
    DF.to_csv(file_path, sep="\t")

# %%
csvfiles= glob.glob(os.path.join(path, "No_NC_*.csv"))
for csvfile in csvfiles:
    noise_flt(csvfile)

# %% [markdown]
# c) Replace the presence of a feature with NaN if the feature is present in only 1 out of 3 replicates

# %%
def rep_filter(csvfile):
    Features= pd.read_csv(csvfile, sep="\t", index_col="Unnamed: 0")
    Features= Features.set_index(["m/z", "RT (s)"])
    Features= Features.sort_index(axis=1)
    cols= Features.columns
    Features= Features.fillna(0)
    Features= Features.transpose()
    Features= Features.reset_index()
    Features['genomeID']=Features['index'].str.extract(r'(NBC_?\d*)')
    Features['genomeID_MDNA']=Features['index'].str.extract(r'(MDNAWGS?\d*|MDNA_WGS_?\d*)')
    Features['genomeID']=Features['genomeID'].fillna(Features['genomeID_MDNA'])
    Features= Features.drop(columns=["genomeID_MDNA"])
    Features=Features.set_index(["index"])
    Grouped= Features.groupby("genomeID")
    DF= Grouped.transform(lambda x: np.nan if np.count_nonzero(x)<2 else x)
    DF=DF.transpose()
    DF=DF.reset_index()
    file_path = os.path.join(os.path.dirname(csvfile), os.path.basename(csvfile)[10:])
    DF.to_csv(file_path, sep="\t", index=None)

# %%
csvfiles= glob.glob(os.path.join(path, "noise_thr_*.csv"))
for csvfile in csvfiles:
    rep_filter(csvfile)

# %% [markdown]
# - Merge all tables on mz and RT:

# %%
Matrix_FPY12= pd.read_csv(os.path.join(path, "FPY12_DF_features.csv"), sep="\t")
Matrix_ISP2= pd.read_csv(os.path.join(path, "ISP2_DF_features.csv"), sep="\t")
Matrix_DNPM= pd.read_csv(os.path.join(path, "DNPM_DF_features.csv"), sep="\t")

Matrix_ISP2= Matrix_ISP2.set_index(["m/z", "RT (s)"])
Matrix_ISP2= Matrix_ISP2.fillna(0)
Matrix_ISP2= Matrix_ISP2.sort_index(axis=1)

Matrix_FPY12= Matrix_FPY12.set_index(["m/z", "RT (s)"])
Matrix_FPY12= Matrix_FPY12.sort_index(axis=1)
Matrix_FPY12= Matrix_FPY12.fillna(0)

Matrix_DNPM= Matrix_DNPM.set_index(["m/z", "RT (s)"])
Matrix_DNPM= Matrix_DNPM.fillna(0)
Matrix_DNPM= Matrix_DNPM.sort_index(axis=1)

Matrix_ISP2_FPY12= pd.merge(Matrix_FPY12, Matrix_ISP2, on=["m/z", "RT (s)"], how="outer")
Matrix= pd.merge(Matrix_ISP2_FPY12, Matrix_DNPM, on=["m/z", "RT (s)"],how= "outer")
cols= Matrix.columns
Matrix[cols] = Matrix[cols].replace({0:np.nan})
Matrix= Matrix.dropna(how="all")
Matrix= Matrix.reset_index()
Matrix.to_csv(os.path.join(path, "Matrix_Clean.csv"), sep="\t", index=None)
